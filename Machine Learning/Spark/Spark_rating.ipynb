# %%
# !pip install pypi-install
# Out:
# Collecting pypi-install
#   Downloading https://files.pythonhosted.org/packages/94/78/0e4a9b9b7dccbe61f10557f9bc1786523491845f9e10b181cf3ca1ee27d5/pypi_install-0.0.5.tar.gz
# Building wheels for collected packages: pypi-install
#   Building wheel for pypi-install (setup.py) ... done
#   Created wheel for pypi-install: filename=pypi_install-0.0.5-cp36-none-any.whl size=4975 sha256=526d9805ce1bdc41b62eb54171e19108a8dc3e7bd41d9996d7eb0e39be71c346
#   Stored in directory: /root/.cache/pip/wheels/ed/bd/a7/a2c486a85277d811aff00290ec75e2380dae49431d7ef11fc5
# Successfully built pypi-install
# Installing collected packages: pypi-install
# Successfully installed pypi-install-0.0.5

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/f0/26/198fc8c0b98580f617cb03cb298c6056587b8f0447e20fa40c5b634ced77/pyspark-3.0.1.tar.gz (204.2MB)
#      |████████████████████████████████| 204.2MB 73kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 45.4MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.1-py2.py3-none-any.whl size=204612242 sha256=04bd3467da6927dd9f2d8aca1a6d015a33b15e6b825695bb874ee38fc2062237
#   Stored in directory: /root/.cache/pip/wheels/5e/bd/07/031766ca628adec8435bb40f0bd83bb676ce65ff4007f8e73f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.0.1

# %%
from pyspark import SparkConf, SparkContext
import collections

# %%
conf = SparkConf().setMaster("local").setAppName("RatingsHistogram")
sc = SparkContext(conf = conf)

# %%
lines = sc.textFile("u.data")
ratings = lines.map(lambda x: x.split()[2])
result = ratings.countByValue()


sortedResults = collections.OrderedDict(sorted(result.items()))
for key, value in sortedResults.items():
    print("%s %i" % (key, value))
# Out:
# 1 6110
# 2 11370
# 3 27145
# 4 34174
# 5 21201
